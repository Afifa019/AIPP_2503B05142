# %%
# !pip install ipython-sql
# %load_ext sql

# Connect to SQLite database
# %sql sqlite:///library.db
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import prettytable

# Create a fallback DEFAULT style so ipython-sql stops crashing
prettytable.DEFAULT = prettytable.MARKDOWN

# %%
#TASK_1
# %%sql

-- DROP OLD TABLES
DROP TABLE IF EXISTS Loans;
DROP TABLE IF EXISTS Books;
DROP TABLE IF EXISTS Members;

-- CREATE TABLE: Members
CREATE TABLE Members (
    member_id INT PRIMARY KEY,
    name VARCHAR(100),
    email VARCHAR(100) UNIQUE,
    join_date DATE
);

-- CREATE TABLE: Books
CREATE TABLE Books (
    book_id INT PRIMARY KEY,
    title VARCHAR(200),
    author VARCHAR(100),
    available BOOLEAN
);

-- CREATE TABLE: Loans
CREATE TABLE Loans (
    loan_id INT PRIMARY KEY,
    member_id INT,
    book_id INT,
    loan_date DATE,
    return_date DATE,
    FOREIGN KEY (member_id) REFERENCES Members(member_id),
    FOREIGN KEY (book_id) REFERENCES Books(book_id)
);
# Out:
#  * sqlite:///library.db
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///library.db
# Done.
# [('Members',), ('Books',), ('Loans',)]

# %%
# %%sql
#
# INSERT INTO Members (member_id, name, email, join_date) VALUES
# (1, 'fathima', 'fathima@gmail.com', '2025-10-14'),
# (2, 'hello', 'hello@gmail.com', '2025-10-15'),
# (3, 'john', 'abc@gmail.com', '2025-11-16');
#
# INSERT INTO Books (book_id, title, author, available) VALUES
# (101, 'Introduction to Databases', 'C.J. Date', TRUE),
# (102, 'The Silent Patient', 'Alex Michaelides', TRUE),
# (103, 'Clean Code', 'Robert C. Martin', TRUE);
#
# INSERT INTO Loans (loan_id, member_id, book_id, loan_date, return_date) VALUES
# (1, 1, 101, '2025-10-10', NULL),
# (2, 2, 102, '2025-10-12', '2025-10-25'),
# (3, 3, 103, '2025-10-15', '2025-12-29');
# Out:
#  * sqlite:///library.db
# 3 rows affected.
# 3 rows affected.
# 3 rows affected.
# []

# %%
# %%sql
#
# SELECT
#     Members.name,
#     Books.book_id,
#     Books.title,
#     Books.author,
#     Loans.loan_date,
#     Loans.return_date
# FROM Loans
# JOIN Members ON Loans.member_id = Members.member_id
# JOIN Books ON Loans.book_id = Books.book_id
# WHERE Members.name = 'Syeda';
# Out:
#  * sqlite:///library.db
# Done.
# []

# %%
# %%sql
# UPDATE Books
# SET available = FALSE
# WHERE book_id = 101;
# Out:
#  * sqlite:///library.db
# 1 rows affected.
# []

# %%
# %%sql
# DELETE FROM Members
# WHERE member_id = 3
# AND member_id  IN (
#     SELECT member_id FROM Loans WHERE return_date IS '2025-12-29'
# );
# Out:
#  * sqlite:///library.db
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Members;
# Out:
#  * sqlite:///library.db
# Done.
# [(1, 'fathima', 'fathima@gmail.com', '2025-10-14'),
#  (2, 'hello', 'hello@gmail.com', '2025-10-15')]

# %%
# %%sql
# SELECT * FROM Loans;
# Out:
#  * sqlite:///library.db
# Done.
# [(1, 1, 101, '2025-10-10', None),
#  (2, 2, 102, '2025-10-12', '2025-10-25'),
#  (3, 3, 103, '2025-10-15', '2025-12-29')]

# %%
# %%sql
# SELECT * FROM Loans;
# Out:
#  * sqlite:///library.db
# Done.
# [(1, 1, 101, '2025-10-10', None),
#  (2, 2, 102, '2025-10-12', '2025-10-25'),
#  (3, 3, 103, '2025-10-15', '2025-12-29')]
